# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
    "font.size": 16,
    })


from fiesta.train.Benchmarker import Benchmarker
from fiesta.inference.lightcurve_model import AfterglowFlux, BullaLightcurveModel

# %%
def high_error_fraction(test, pred, filt):
    err = np.max(np.abs(test[filt]-pred[filt]), axis=1)

    err = err[(~np.isnan(err)) & (~np.isinf(err))]

    return np.sum(err >1) / len(err)

# %% [markdown]
# ## Bu2025  CVAE vs. MLP

# %%
FILTERS = ["besselli", "bessellv", "bessellux"]


model1 = AfterglowFlux("Bu2025_MLP",
                        filters = FILTERS)

model2 = AfterglowFlux("Bu2025_CVAE",
                        filters = FILTERS)


benchmarker1 = Benchmarker(
                    model = model1,
                    data_file = "/home/aya/work/hkoehn/fiesta/fiesta/surrogates/KN/training_data/Bu2025_raw_data.h5",
                    metric_name = "L2"
                    )

benchmarker2 = Benchmarker(
                    model = model2,
                    data_file = "/home/aya/work/hkoehn/fiesta/fiesta/surrogates/KN/training_data/Bu2025_raw_data.h5",
                    metric_name = "L2"
                    )
# Out:
# 14:00 fiesta INFO    : Loading surrogate Bu2025_MLP. This surrogate should only be used in the following parameter ranges:
# 14:00 fiesta INFO    : 	 log10_mej_dyn: (-3.0, -1.3010299956639813)
# 14:00 fiesta INFO    : 	 v_ej_dyn: (0.12, 0.28)
# 14:00 fiesta INFO    : 	 Ye_dyn: (0.15, 0.35)
# 14:00 fiesta INFO    : 	 log10_mej_wind: (-2.0, -0.8860566476931633)
# 14:00 fiesta INFO    : 	 v_ej_wind: (0.05, 0.15)
# 14:00 fiesta INFO    : 	 Ye_wind: (0.2, 0.4)
# 14:00 fiesta INFO    : 	 inclination_EM: (0.0, 90.0)
# 14:00 fiesta INFO    : Surrogate Bu2025_MLP is loading with the following filters: ['besselli', 'bessellv', 'bessellux'].
# 14:00 fiesta INFO    : Loaded for surrogate Bu2025_MLP from /nfs/aya/work/hkoehn/fiesta/fiesta/surrogates/KN/Bu2025_MLP/model.
# 14:00 fiesta INFO    : Loading surrogate Bu2025_CVAE. This surrogate should only be used in the following parameter ranges:
# 14:00 fiesta INFO    : 	 log10_mej_dyn: (-3.0, -1.3010299956639813)
# 14:00 fiesta INFO    : 	 v_ej_dyn: (0.12, 0.28)
# 14:00 fiesta INFO    : 	 Ye_dyn: (0.15, 0.35)
# 14:00 fiesta INFO    : 	 log10_mej_wind: (-2.0, -0.8860566476931633)
# 14:00 fiesta INFO    : 	 v_ej_wind: (0.05, 0.15)
# 14:00 fiesta INFO    : 	 Ye_wind: (0.2, 0.4)
# 14:00 fiesta INFO    : 	 inclination_EM: (0.0, 90.0)
# 14:00 fiesta INFO    : Surrogate Bu2025_CVAE is loading with the following filters: ['besselli', 'bessellv', 'bessellux'].
# 14:00 fiesta INFO    : Loaded for surrogate Bu2025_CVAE from /nfs/aya/work/hkoehn/fiesta/fiesta/surrogates/KN/Bu2025_CVAE/model.
# Loaded filters are: ['besselli', 'bessellv', 'bessellux'].
# Loaded filters are: ['besselli', 'bessellv', 'bessellux'].

# %%
fig, ax = plt.subplots(3, 2, figsize = (9, 12))
fig.subplots_adjust(wspace = 0.4, hspace =0.35, bottom = 0.05, top = 0.95, left = 0.05, right = 0.95)

for filter, cax in zip(FILTERS, ax[:,0]):

    cax.hist(benchmarker1.error[filter], color = "blue", histtype = "step", bins = np.linspace(0, 1, 20), density = True, label = "MLP")
    cax.hist(benchmarker2.error[filter], color = "green", histtype = "step", bins = np.linspace(0, 1, 20), density = True, label = "cVAE")
    cax.set_yticks([])
    cax.set_xlabel("mean square error in mag")
    cax.set_xlim((0,1))
    cax.set_title(filter, loc = "left")

for filter, cax in zip(FILTERS, ax[:,1]):
    error = np.abs(benchmarker1.pred_mag[filter] - benchmarker1.test_mag[filter])
    error[np.isinf(error) | np.isnan(error)] = 0.
    indices = np.linspace(10, len(model1.times)-5, 6).astype(int)
    parts1 = cax.violinplot(error[:, indices], positions=np.log10(model1.times[indices]), widths=0.25, side="low", showextrema=False, points=500)
    for pc in parts1["bodies"]:
        pc.set_facecolor("blue")
        pc.set_edgecolor("blue")

    error = np.abs(benchmarker2.pred_mag[filter] - benchmarker2.test_mag[filter])
    error[np.isinf(error) | np.isnan(error)] = 0.
    indices = np.linspace(10, len(model2.times)-5, 6).astype(int)
    parts2 = cax.violinplot(error[:, indices], positions=np.log10(model2.times[indices]), widths=0.25, side="high", showextrema=False, points=500)
    for pc in parts2["bodies"]:
        pc.set_facecolor("green")
        pc.set_edgecolor("green")

    cax.set(xlabel = "$\\log_{10}(t)$ in days", ylabel = "error in mag", xscale = "linear", xlim = (-0.5, np.log10(20)), ylim = (0,1))

ax[0,0].legend(fancybox=False, framealpha=1, fontsize = 16)
fig.savefig("./benchmark_Bu2025.pdf", dpi =300)

# %% [markdown]
# # Bu2025 lc vs. MLP

# %%
FILTERS = ["besselli", "bessellv", "bessellux"]


model1 = AfterglowFlux("Bu2025_MLP",
                        filters = FILTERS)

model2 = BullaLightcurveModel("Bu2025",
                              filters = FILTERS)


benchmarker1 = Benchmarker(
                    model = model1,
                    data_file = "/home/aya/work/hkoehn/fiesta/fiesta/surrogates/KN/training_data/Bu2025_raw_data.h5",
                    metric_name = "L2"
                    )

benchmarker2 = Benchmarker(
                    model = model2,
                    data_file = "/home/aya/work/hkoehn/fiesta/fiesta/surrogates/KN/training_data/Bu2025_raw_data.h5",
                    metric_name = "L2"
                    )
# Out:
# 11:17 fiesta INFO    : Loading surrogate Bu2025_MLP. This surrogate should only be used in the following parameter ranges:
# 11:17 fiesta INFO    : 	 log10_mej_dyn: (-3.0, -1.3010299956639813)
# 11:17 fiesta INFO    : 	 v_ej_dyn: (0.12, 0.28)
# 11:17 fiesta INFO    : 	 Ye_dyn: (0.15, 0.35)
# 11:17 fiesta INFO    : 	 log10_mej_wind: (-2.0, -0.8860566476931633)
# 11:17 fiesta INFO    : 	 v_ej_wind: (0.05, 0.15)
# 11:17 fiesta INFO    : 	 Ye_wind: (0.2, 0.4)
# 11:17 fiesta INFO    : 	 inclination_EM: (0.0, 90.0)
# 11:17 fiesta INFO    : Surrogate Bu2025_MLP is loading with the following filters: ['besselli', 'bessellv', 'bessellux'].
# 11:17 fiesta INFO    : Loaded for surrogate Bu2025_MLP from /nfs/aya/work/hkoehn/fiesta/fiesta/surrogates/KN/Bu2025_MLP/model.
# 11:17 fiesta INFO    : Loading surrogate Bu2025. This surrogate should only be used in the following parameter ranges:
# 11:17 fiesta INFO    : 	 log10_mej_dyn: (-3.0, -1.3010299956639813)
# 11:17 fiesta INFO    : 	 v_ej_dyn: (0.12, 0.28)
# 11:17 fiesta INFO    : 	 Ye_dyn: (0.15, 0.35)
# 11:17 fiesta INFO    : 	 log10_mej_wind: (-2.0, -0.8860566476931633)
# 11:17 fiesta INFO    : 	 v_ej_wind: (0.05, 0.15)
# 11:17 fiesta INFO    : 	 Ye_wind: (0.2, 0.4)
# 11:17 fiesta INFO    : 	 inclination_EM: (0.0, 90.0)
# 11:17 fiesta INFO    : 	 redshift: (0, 0.5)
# 11:17 fiesta INFO    : Surrogate Bu2025 is loading with the following filters: ['besselli', 'bessellv', 'bessellux'].
# 11:17 fiesta INFO    : Loaded for surrogate Bu2025 from /nfs/aya/work/hkoehn/fiesta/fiesta/surrogates/KN/Bu2025_lc/model.
# /nfs/aya/work/hkoehn/fiesta/fiesta/surrogates/KN/Bu2025_MLP/model
# /nfs/aya/work/hkoehn/fiesta/fiesta/surrogates/KN/Bu2025_lc/model
# Loaded filters are: ['besselli', 'bessellv', 'bessellux'].
# Loaded filters are: ['besselli', 'bessellv', 'bessellux'].

# %%
fig, ax = plt.subplots(3, 2, figsize = (9, 12))
fig.subplots_adjust(wspace = 0.4, hspace =0.35, bottom = 0.05, top = 0.95, left = 0.05, right = 0.95)

for filter, cax in zip(FILTERS, ax[:,0]):

    cax.hist(benchmarker1.error[filter], color = "blue", histtype = "step", bins = np.linspace(0, 1, 20), density = True, label = "MLP (Flux)")
    cax.hist(benchmarker2.error[filter], color = "green", histtype = "step", bins = np.linspace(0, 1, 20), density = True, label = "MLP (Lightcurve)")
    cax.set_yticks([])
    cax.set_xlabel("mean square error in mag")
    cax.set_xlim((0,1))
    cax.set_title(filter, loc = "left")

for filter, cax in zip(FILTERS, ax[:,1]):
    error = np.abs(benchmarker1.pred_mag[filter] - benchmarker1.test_mag[filter])
    error[np.isinf(error) | np.isnan(error)] = 0.
    indices = np.linspace(10, len(model1.times)-5, 6).astype(int)
    parts1 = cax.violinplot(error[:, indices], positions=np.log10(model1.times[indices]), widths=0.25, side="low", showextrema=False, points=500)
    for pc in parts1["bodies"]:
        pc.set_facecolor("blue")
        pc.set_edgecolor("blue")

    error = np.abs(benchmarker2.pred_mag[filter] - benchmarker2.test_mag[filter])
    error[np.isinf(error) | np.isnan(error)] = 0.
    indices = np.linspace(10, len(model2.times)-5, 6).astype(int)
    parts2 = cax.violinplot(error[:, indices], positions=np.log10(model2.times[indices]), widths=0.25, side="high", showextrema=False, points=500)
    for pc in parts2["bodies"]:
        pc.set_facecolor("green")
        pc.set_edgecolor("green")

    cax.set(xlabel = "$\\log_{10}(t)$ in days", ylabel = "error in mag", xscale = "linear", xlim = (-0.5, np.log10(20)), ylim = (0,1))

ax[0,0].legend(fancybox=False, framealpha=1, fontsize = 16)
fig.savefig("./benchmark_Bu2025.pdf", dpi =300)

# %%
high_error_fraction(benchmarker1.test_mag, benchmarker1.pred_mag, "bessellux")
# Out:
# 0.8634197199880846

# %%
benchmarker1.times[0]
# Out:
# 0.2904534698848371

# %%
np.argsort(np.abs(benchmarker1.test_mag["bessellux"][:,42] - benchmarker1.pred_mag["bessellux"][:,42]))[-20:]
# Out:
# array([2015,  905,  700, 2066, 1760,  320,  141, 2152, 1866, 1674, 1666,
#         877, 2056,  389,  167,  108, 1982, 1095, 1976, 1670])

# %%
plt.plot(benchmarker1.test_mag["besselli"][108], color="lightskyblue", linestyle="dashed")
plt.plot(benchmarker1.pred_mag["besselli"][108], color="red")
plt.gca().invert_yaxis()

# %%
-10 + 5*(np.log10(4e7)-1)
# Out:
# 23.010299956639813
